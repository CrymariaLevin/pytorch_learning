# %%
# 3d图片读取
import torch
import numpy as np
torch.set_printoptions(edgeitems=2, threshold=50)

# %%
import imageio

# %%
# 3d图片要用volread函数
dir_path = "../data/p1ch4/volumetric-dicom/2-LUNG 3.0  B70f-04083"
vol_arr = imageio.volread(dir_path, 'DICOM')
vol_arr.shape # 可理解为99张图片叠起来的
# Out:
# Reading DICOM (examining files): 1/99 files (1.0%61/99 files (61.6%99/99 files (100.0%)
#   Found 1 correct series.
# Reading DICOM (loading data): 44/99  (44.489/99  (89.999/99  (100.0%)
# (99, 512, 512)

# %%
vol = torch.from_numpy(vol_arr).float()
vol = torch.unsqueeze(vol, 0)

vol.shape
# Out:
# torch.Size([1, 99, 512, 512])

# %%
# 横切面
# %matplotlib notebook
import matplotlib.pyplot as plt

plt.imshow(vol_arr[44])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# 纵切面（正面）
# %matplotlib notebook
import matplotlib.pyplot as plt

plt.imshow(vol_arr[:,200,:])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# 竖切面
# %matplotlib notebook
import matplotlib.pyplot as plt

plt.imshow(vol_arr[:,:,100])
# Out:
# <img src="data:image/png;base64,..." width="640">
